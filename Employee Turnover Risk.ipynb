# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('HR_comma_sep.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.rename(columns={'sales': 'department'}, inplace=True)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# dtype: int64

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# ### Step 2: EDA with Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='whitegrid', palette='muted')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## Correlation Heat Map

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numeric Features')
plt.show()

# %% [markdown]
# ### Distribution plot of Satisfaction Level

# %%
sns.histplot(df['satisfaction_level'], kde=True, bins=30, color='skyblue')
plt.title('Distribution of Satisfaction Level')
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Distribution plot of Last Evaluation

# %%
sns.histplot(df['last_evaluation'], kde=True, bins=30, color='salmon')
plt.title('Distribution of Last Evaluation')
plt.xlabel('Last Evaluation')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Distribution plot of Avg Monthly Hours

# %%
sns.histplot(df['average_montly_hours'], kde=True, bins=30, color='seagreen')
plt.title('Distribution of Average Monthly Hours')
plt.xlabel('Average Monthly Hours')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Bar Plot of Project Count for Employees

# %%
df['left_str'] = df['left'].map({0: 'Stayed', 1: 'Left'})

sns.countplot(x='number_project', hue='left_str', data=df, palette={'Stayed': 'lightgreen', 'Left': 'salmon'})
plt.title('Project Count Comparison: Stayed vs Left')
plt.xlabel('Number of Projects')
plt.ylabel('Number of Employees')
plt.legend(title='Employee Status')
plt.show()

# %% [markdown]
# # Inference

# %%
fig, axs = plt.subplots(2, 2, figsize=(18, 12))
sns.set(style='whitegrid')

sns.histplot(df['satisfaction_level'], kde=True, bins=30, color='skyblue', ax=axs[0, 0])
axs[0, 0].set_title('Distribution of Satisfaction Level')
axs[0, 0].set_xlabel('Satisfaction Level')
axs[0, 0].set_ylabel('Number of Employees')

sns.histplot(df['last_evaluation'], kde=True, bins=30, color='salmon', ax=axs[0, 1])
axs[0, 1].set_title('Distribution of Last Evaluation')
axs[0, 1].set_xlabel('Last Evaluation Score')
axs[0, 1].set_ylabel('Number of Employees')

sns.histplot(df['average_montly_hours'], kde=True, bins=30, color='seagreen', ax=axs[1, 0])
axs[1, 0].set_title('Distribution of Average Monthly Hours')
axs[1, 0].set_xlabel('Monthly Hours')
axs[1, 0].set_ylabel('Number of Employees')

df['left_str'] = df['left'].map({0: 'Stayed', 1: 'Left'})
sns.countplot(x='number_project', hue='left_str', data=df, palette={'Stayed': 'lightgreen', 'Left': 'salmon'}, ax=axs[1, 1])
axs[1, 1].set_title('Project Count vs Turnover Status')
axs[1, 1].set_xlabel('Number of Projects')
axs[1, 1].set_ylabel('Number of Employees')
axs[1, 1].legend(title='Status')

plt.tight_layout()
plt.suptitle("📊 Employee Turnover Dashboard – Portobello Tech", fontsize=18, y=1.02)
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## For 2 Projects more employees left than stayed and under-utilization may lead to disinterest
# ## For 3-4 Projects majority stayed which may represent a healthy workload range
# ## For 5 Projects there is a slight drop in retention
# ## For 6-7 Projects there is a sharp increase in people leaving hence overwork and burnout risk increases drastically

# %% [markdown]
# # K means Clustering

# %%
from sklearn.cluster import KMeans

# %%
left_employees= df[df['left']==1][['satisfaction_level', 'last_evaluation']]
left_employees
# Out:
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [3571 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
left_employees['cluster'] = kmeans.fit_predict(left_employees)

plt.figure(figsize=(8, 4))
sns.scatterplot(
    x='satisfaction_level',
    y='last_evaluation',
    hue='cluster',
    palette='Set1',
    data=left_employees
)
plt.title('K-Means Clustering of Employees Who Left')
plt.xlabel('Satisfaction Level')
plt.ylabel('Last Evaluation')
plt.legend(title='Cluster')
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ### Cluster 0 has a big cluster of underperforming employees
# ### Cluster 1 has medium to high performing employees but may be they were overburdened hence least satisfied
# ### Cluster 3 has highly performing employees with highest satisfaction so they might have left for even better options or personal reasons

# %%
# Mean values for each cluster
cluster_summary = left_employees.groupby('cluster').mean().round(2)
print("📋 Cluster Summary:\n", cluster_summary)
# Out:
# 📋 Cluster Summary:
#           satisfaction_level  last_evaluation
# cluster
# 0                      0.48             0.58
# 1                      0.11             0.87
# 2                      0.83             0.96

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# %%
if 'left_str' in df.columns:
    df.drop(columns=['left_str'], inplace=True)


X = df.drop('left', axis=1)
y = df['left']

# %%
cat_cols = ['department', 'salary']
num_cols = [col for col in X.columns if col not in cat_cols]

# One-hot encode categorical columns
X_cat = pd.get_dummies(X[cat_cols], drop_first=True)
X_num = X[num_cols]

# Combine processed categorical and numerical columns
X_final = pd.concat([X_num, X_cat], axis=1)

# %% [markdown]
# ## Train Test Split

# %%
# Stratified split to preserve class distribution
X_train, X_test, y_train, y_test = train_test_split(
    X_final, y, test_size=0.2, random_state=123, stratify=y
)

print("Before SMOTE:")
print(y_train.value_counts())
# Out:
# Before SMOTE:
# left
# 0    9142
# 1    2857
# Name: count, dtype: int64

# %%
smote = SMOTE(random_state=123)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print("After SMOTE:")
print(y_train_smote.value_counts())
# Out:
# After SMOTE:
# left
# 0    9142
# 1    9142
# Name: count, dtype: int64

# %% [markdown]
# # 5 fold cross validation and model training
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report

# Logistic Regression Model
log_reg = LogisticRegression(max_iter=1000, random_state=123)

# Cross-validated predictions
y_pred_log = cross_val_predict(log_reg, X_train_smote, y_train_smote, cv=5)

print("📊 Logistic Regression Classification Report:\n")
print(classification_report(y_train_smote, y_pred_log))
# Out:
# 📊 Logistic Regression Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79      9142
#            1       0.78      0.82      0.80      9142
#
#     accuracy                           0.79     18284
#    macro avg       0.80      0.79      0.79     18284
# weighted avg       0.80      0.79      0.79     18284

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Random Forest
rf = RandomForestClassifier(random_state=123)
y_pred_rf = cross_val_predict(rf, X_train_smote, y_train_smote, cv=5)

print("🌲 Random Forest Classification Report:\n")
print(classification_report(y_train_smote, y_pred_rf))
# Out:
# 🌲 Random Forest Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      9142
#            1       1.00      0.97      0.98      9142
#
#     accuracy                           0.98     18284
#    macro avg       0.98      0.98      0.98     18284
# weighted avg       0.98      0.98      0.98     18284

# %% [markdown]
# ## Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Gradient Boosting
gb = GradientBoostingClassifier(random_state=123)
y_pred_gb = cross_val_predict(gb, X_train_smote, y_train_smote, cv=5)

print("🔥 Gradient Boosting Classification Report:\n")
print(classification_report(y_train_smote, y_pred_gb))
# Out:
# 🔥 Gradient Boosting Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      9142
#            1       0.98      0.95      0.96      9142
#
#     accuracy                           0.96     18284
#    macro avg       0.96      0.96      0.96     18284
# weighted avg       0.96      0.96      0.96     18284

# %% [markdown]
# # ROC-AUC Curve

# %%
from sklearn.metrics import roc_curve, auc

# Model fitting
log_reg.fit(X_train_smote, y_train_smote)
rf.fit(X_train_smote, y_train_smote)
gb.fit(X_train_smote, y_train_smote)

# Probabilities for ROC
y_prob_log = log_reg.predict_proba(X_test)[:, 1]
y_prob_rf = rf.predict_proba(X_test)[:, 1]
y_prob_gb = gb.predict_proba(X_test)[:, 1]

# ROC curves
fpr_log, tpr_log, _ = roc_curve(y_test, y_prob_log)
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_prob_rf)
fpr_gb, tpr_gb, _ = roc_curve(y_test, y_prob_gb)

# AUC scores
auc_log = auc(fpr_log, tpr_log)
auc_rf = auc(fpr_rf, tpr_rf)
auc_gb = auc(fpr_gb, tpr_gb)


plt.figure(figsize=(10, 6))
plt.plot(fpr_log, tpr_log, label=f'Logistic Regression (AUC = {auc_log:.2f})')
plt.plot(fpr_rf, tpr_rf, label=f'Random Forest (AUC = {auc_rf:.2f})')
plt.plot(fpr_gb, tpr_gb, label=f'Gradient Boosting (AUC = {auc_gb:.2f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random Chance')

plt.title('ROC Curve Comparison')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import confusion_matrix

y_test_pred_log = log_reg.predict(X_test)
y_test_pred_rf = rf.predict(X_test)
y_test_pred_gb = gb.predict(X_test)

# Confusion Matrices
print("📘 Logistic Regression Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred_log))
print("\n🌲 Random Forest Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred_rf))
print("\n🔥 Gradient Boosting Confusion Matrix:\n", confusion_matrix(y_test, y_test_pred_gb))
# Out:
# 📘 Logistic Regression Confusion Matrix:
#  [[1767  519]
#  [ 184  530]]
#
# 🌲 Random Forest Confusion Matrix:
#  [[2271   15]
#  [  16  698]]
#
# 🔥 Gradient Boosting Confusion Matrix:
#  [[2231   55]
#  [  49  665]]

# %%
# In employee turnover prediction, our goal is to catch "true leavers" so that HR can intervene.

#Recall (Sensitivity) is critical:

#“Of all employees who were actually going to leave, how many did we correctly predict?”

#Precision matters too, but lower recall would mean we miss people who are at risk.

#✅ So our priority metric is: Recall for class 1 (leavers)

# %% [markdown]
# # Turnover probabilities

# %%
# Predicting the probability of class 1 (employee leaving)
y_test_probs = rf.predict_proba(X_test)[:, 1]


prob_df = pd.DataFrame({
    'Actual Left': y_test,
    'Probability of Leaving': y_test_probs
})

def categorize_risk(score):
    if score < 0.20:
        return 'Safe Zone (Green)'
    elif score < 0.60:
        return 'Low-Risk Zone (Yellow)'
    elif score < 0.90:
        return 'Medium-Risk Zone (Orange)'
    else:
        return 'High-Risk Zone (Red)'

prob_df['Risk Zone'] = prob_df['Probability of Leaving'].apply(categorize_risk)

# Count employees in each zone
zone_counts = prob_df['Risk Zone'].value_counts()
print("📊 Employee Count by Risk Zone:\n")
print(zone_counts)
# Out:
# 📊 Employee Count by Risk Zone:
#
# Risk Zone
# Safe Zone (Green)            2174
# High-Risk Zone (Red)          649
# Low-Risk Zone (Yellow)        122
# Medium-Risk Zone (Orange)      55
# Name: count, dtype: int64

# %%
prob_df
# Out:
#        Actual Left  Probability of Leaving               Risk Zone
# 10627            0                    0.00       Safe Zone (Green)
# 2703             0                    0.59  Low-Risk Zone (Yellow)
# 6059             0                    0.05       Safe Zone (Green)
# 3258             0                    0.01       Safe Zone (Green)
# 4565             0                    0.00       Safe Zone (Green)
# ...            ...                     ...                     ...
# 4961             0                    0.00       Safe Zone (Green)
# 4557             0                    0.06       Safe Zone (Green)
# 6610             0                    0.02       Safe Zone (Green)
# 10327            0                    0.06       Safe Zone (Green)
# 731              1                    1.00    High-Risk Zone (Red)
#
# [3000 rows x 3 columns]

# %% [markdown]
# # Creating a pie to plot

# %%
# Count the risk zones
zone_counts = prob_df['Risk Zone'].value_counts()


colors = {
    'Safe Zone (Green)': '#4CAF50',
    'Low-Risk Zone (Yellow)': '#FFEB3B',
    'Medium-Risk Zone (Orange)': '#FF9800',
    'High-Risk Zone (Red)': '#F44336'
}


plt.figure(figsize=(4, 4))
plt.pie(zone_counts, 
        labels=zone_counts.index,
        colors=[colors[label] for label in zone_counts.index],
        autopct='%1.1f%%',
        startangle=140,
        wedgeprops=dict(width=0.4))  # for a donut look

plt.title('📊 Employee Turnover Risk Distribution', fontsize=14)
plt.axis('equal')  # Equal aspect ratio makes the pie round
plt.show()
# Out:
# C:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from matplotlib.backends.backend_pdf import PdfPages


zone_counts = prob_df['Risk Zone'].value_counts()
colors = {
    'Safe Zone (Green)': '#4CAF50',
    'Low-Risk Zone (Yellow)': '#FFEB3B',
    'Medium-Risk Zone (Orange)': '#FF9800',
    'High-Risk Zone (Red)': '#F44336'
}

fig1, ax1 = plt.subplots(figsize=(8, 6))
ax1.pie(zone_counts, 
        labels=zone_counts.index,
        colors=[colors[label] for label in zone_counts.index],
        autopct='%1.1f%%',
        startangle=140,
        wedgeprops=dict(width=0.4))
ax1.set_title('📊 Employee Turnover Risk Distribution')


fig2, ax2 = plt.subplots(figsize=(10, 6))
ax2.axis('off')
table_data = prob_df[['Actual Left', 'Probability of Leaving', 'Risk Zone']].head(15)
table = ax2.table(cellText=table_data.values, colLabels=table_data.columns, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.5)
ax2.set_title('📋 Sample of Predictions (Top 15 Rows)', fontsize=14)


with PdfPages('Employee_Turnover_Risk_Report.pdf') as pdf:
    pdf.savefig(fig1)
    pdf.savefig(fig2)

print("✅ PDF Report Generated: 'Employee_Turnover_Risk_Report.pdf'")
# Out:
# C:\Users\harde\AppData\Local\Temp\ipykernel_21628\3021637691.py:33: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   pdf.savefig(fig1)
# C:\Users\harde\AppData\Local\Temp\ipykernel_21628\3021637691.py:34: UserWarning: Glyph 128203 (\N{CLIPBOARD}) missing from current font.
#   pdf.savefig(fig2)
# ✅ PDF Report Generated: 'Employee_Turnover_Risk_Report.pdf'
# C:\Anaconda\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   func(*args, **kwargs)
# C:\Anaconda\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 128203 (\N{CLIPBOARD}) missing from current font.
#   func(*args, **kwargs)
# C:\Anaconda\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
pip install pypandoc
# Out:
# ...
#
# ...
